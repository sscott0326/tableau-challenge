# %%
import pandas as pd

# %%
data_2019_01 = pd.read_csv("Resources/raw_data/201901-citibike-tripdata.csv")
data_2019_02 = pd.read_csv("Resources/raw_data/201902-citibike-tripdata.csv")
data_2019_03 = pd.read_csv("Resources/raw_data/201903-citibike-tripdata.csv")
data_2019_04 = pd.read_csv("Resources/raw_data/201904-citibike-tripdata.csv")
data_2019_05 = pd.read_csv("Resources/raw_data/201905-citibike-tripdata.csv")

# %%
data_2019_01["Month"] = "January"
data_2019_02["Month"] = "February"
data_2019_03["Month"] = "March"
data_2019_04["Month"] = "April"
data_2019_05["Month"] = "May"

# %%
files_2019 = [data_2019_01,
              data_2019_02,
              data_2019_03,
              data_2019_04,
              data_2019_05]

# %%
for file in files_2019:
    file.drop(['starttime',
               'stoptime',
               'start station id',
               'end station id'], axis=1,inplace=True)
    file.drop(file[file['birth year'] < 1939].index, inplace=True)
    file.drop(file[file['gender'] == 0].index, inplace=True)
    file['gender'].replace({1: "Male", 2:"Female"}, inplace=True)

# %%
data_2019_01
# Out:
#         tripduration           start station name  start station latitude  \
# 0                320  Central Park West & W 76 St               40.778968
# 1                316        Pershing Square North               40.751873
# 2                591      Amsterdam Ave & W 82 St               40.785247
# 3               2719              1 Ave & E 16 St               40.732219
# 4                303               Great Jones St               40.727434
# ...              ...                          ...                     ...
# 967282           291    3 St & Prospect Park West               40.668132
# 967283           437    3 St & Prospect Park West               40.668132
# 967284           173    3 St & Prospect Park West               40.668132
# 967285           244    3 St & Prospect Park West               40.668132
# 967286           387    3 St & Prospect Park West               40.668132
#
#         start station longitude                 end station name  \
# ...

# %%
data_2019_01.to_csv("Resources/clean_data/data_2019_01.csv")
data_2019_02.to_csv("Resources/clean_data/data_2019_02.csv")
data_2019_03.to_csv("Resources/clean_data/data_2019_03.csv")
data_2019_04.to_csv("Resources/clean_data/data_2019_04.csv")
data_2019_05.to_csv("Resources/clean_data/data_2019_05.csv")

# %%
data_2020_01 = pd.read_csv("Resources/raw_data/202001-citibike-tripdata.csv")
data_2020_02 = pd.read_csv("Resources/raw_data/202002-citibike-tripdata.csv")
data_2020_03 = pd.read_csv("Resources/raw_data/202003-citibike-tripdata.csv")
data_2020_04 = pd.read_csv("Resources/raw_data/202004-citibike-tripdata.csv")
data_2020_05 = pd.read_csv("Resources/raw_data/202005-citibike-tripdata.csv")

# %%
data_2020_01["Month"] = "January"
data_2020_02["Month"] = "February"
data_2020_03["Month"] = "March"
data_2020_04["Month"] = "April"
data_2020_05["Month"] = "May"

# %%
files_2020 = [data_2020_01,
              data_2020_02,
              data_2020_03,
              data_2020_04,
              data_2020_05]

# %%
for file in files_2020:
    file.drop(['starttime',
               'stoptime',
               'start station id',
               'end station id'], axis=1,inplace=True)
    file.drop(file[file['birth year'] < 1939].index, inplace=True)
    file.drop(file[file['gender'] == 0].index, inplace=True)
    file['gender'].replace({1: "Male", 2:"Female"}, inplace=True)

# %%
data_2020_05
# Out:
#          tripduration                  start station name  \
# 0                 336                     E 43 St & 2 Ave
# 1                 853                     E 65 St & 2 Ave
# 3                1185  Frederick Douglass Blvd & W 115 St
# 4                 272          Central Ave & Starr Street
# 6                 925                     1 Ave & E 62 St
# ...               ...                                 ...
# 1487884           524          Crescent St & Ditmars Blvd
# 1487885           981           Washington Ave & Park Ave
# 1487886           367                     E 23 St & 1 Ave
# 1487887          1798                     W 49 St & 8 Ave
# 1487889          1168                     Dean St & 4 Ave
#
#          start station latitude  start station longitude  \
# 0                     40.750224               -73.971214
# 1                     40.764719               -73.962221
# 3                     40.803865               -73.955931
# ...

# %%
data_2020_01.to_csv("Resources/clean_data/data_2020_01.csv")
data_2020_02.to_csv("Resources/clean_data/data_2020_02.csv")
data_2020_03.to_csv("Resources/clean_data/data_2020_03.csv")
data_2020_04.to_csv("Resources/clean_data/data_2020_04.csv")
data_2020_05.to_csv("Resources/clean_data/data_2020_05.csv")
